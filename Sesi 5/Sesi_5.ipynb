# %% [markdown]
# # Pandas Introduction

# %%
import numpy as np
import pandas as pd

# %%
# Selain csv ada read_json(), read_html(), read_sql_table()
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
# Menghitung jumlah baris
len(df)
# Out:
# 126314

# %%
# Terdiri dari 126.314 baris dan 23 kolom
df.shape
# Out:
# (126314, 23)

# %%
# Melihat isi 5 data pertama
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
# Untuk melihat keseluruhan isi tabel
pd.set_option("display.max.column", None)

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
df.tail(3)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 126311             A           L      0.23   NaN
# ...

# %% [markdown]
# ## Getting to Know Your Data

# %%
# Untuk melihat daftar semua kolom dalam kumpulan dan jenis data
# Langkah pertama melihat data typer terlebih dahulu
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# ### Showing Basic Statistics

# %%
# Langkah kedua, mendapatkan overview tentang nilai yang terkandung disetiap kolom
# Menampilkan kolom yang mengandung numerical value
df.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
# df['game_id']
# df[['game_id', 'lg_id']]
df[['game_id', 'lg_id', 'pts']]
# Out:
#              game_id lg_id  pts
# 0       194611010TRH   NBA   66
# 1       194611010TRH   NBA   68
# 2       194611020CHS   NBA   63
# 3       194611020CHS   NBA   47
# 4       194611020DTF   NBA   33
# ...              ...   ...  ...
# 126309  201506110CLE   NBA   82
# 126310  201506140GSW   NBA  104
# 126311  201506140GSW   NBA   91
# 126312  201506170CLE   NBA   97
# 126313  201506170CLE   NBA  105
#
# [126314 rows x 3 columns]

# %%
df['pts'].describe()
# Out:
# count    126314.00
# mean        102.73
# std          14.81
# min           0.00
# 25%          93.00
# 50%         103.00
# 75%         112.00
# max         186.00
# Name: pts, dtype: float64

# %%
df['elo_i'].describe()
# Out:
# count    126314.00
# mean       1495.24
# std         112.14
# min        1091.64
# 25%        1417.24
# 50%        1500.95
# 75%        1576.06
# max        1853.10
# Name: elo_i, dtype: float64

# %%
df[['pts', 'elo_i']].describe()
# Out:
#                  pts          elo_i
# count  126314.000000  126314.000000
# mean      102.729982    1495.236055
# std        14.814845     112.139945
# min         0.000000    1091.644500
# 25%        93.000000    1417.237975
# 50%       103.000000    1500.945550
# 75%       112.000000    1576.060000
# max       186.000000    1853.104500

# %%
# pd.set_option("display.precision", 2), digunakan untuk menghilangkan 6 digit dibelakang
pd.reset_option("display.precision")

# %%
# Menampilan kolom selain numerical value
# Unique adalah jumlah data yang unik
df.describe(include=object)
# Out:
#              game_id   lg_id  date_game team_id fran_id  opp_id opp_fran  \
# count         126314  126314     126314  126314  126314  126314   126314
# unique         63157       2      12426     104      53     104       53
# top     194611010TRH     NBA  4/13/2011     BOS  Lakers     BOS   Lakers
# freq               2  118016         30    5997    6024    5997     6024
#
#        game_location game_result           notes
# count         126314      126314            5424
# unique             3           2             231
# top                H           L  at New York NY
# freq           63138       63157             440

# %%
# Melihat keseluruhan
df.describe(include=[object, int])
# Out:
#             gameorder       game_id   lg_id        _iscopy        year_id  \
# count   126314.000000        126314  126314  126314.000000  126314.000000
# unique            NaN         63157       2            NaN            NaN
# top               NaN  194611010TRH     NBA            NaN            NaN
# freq              NaN             2  118016            NaN            NaN
# mean     31579.000000           NaN     NaN       0.500000    1988.200374
# std      18231.927643           NaN     NaN       0.500002      17.582309
# min          1.000000           NaN     NaN       0.000000    1947.000000
# 25%      15790.000000           NaN     NaN       0.000000    1975.000000
# 50%      31579.000000           NaN     NaN       0.500000    1990.000000
# 75%      47368.000000           NaN     NaN       1.000000    2003.000000
# max      63157.000000           NaN     NaN       1.000000    2015.000000
#
#         date_game     seasongame    is_playoffs team_id fran_id  \
# ...

# %% [markdown]
# ### Exploring Your Dataset

# %%
# Menghitung jumlah baris pada setiap team_id
df['team_id'].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
# Menghitung jumlah baris atau permainan pada setiap fran_id
df['fran_id'].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
# Menampilkan team yang franchise idnya "lakers"
filter_fran_lakers = df['fran_id'] == 'Lakers'
df[filter_fran_lakers]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1136          569  194811040BLB   NBA        1     1949   11/4/1948
# 1152          577  194811060WSC   NBA        1     1949   11/6/1948
# 1159          580  194811090BOS   NBA        1     1949   11/9/1948
# 1170          586  194811110NYK   NBA        1     1949  11/11/1948
# 1183          592  194811130PRO   NBA        1     1949  11/13/1948
# ...           ...           ...   ...      ...      ...         ...
# 126016      63009  201504080DEN   NBA        1     2015    4/8/2015
# 126052      63027  201504100LAL   NBA        0     2015   4/10/2015
# 126086      63044  201504120LAL   NBA        0     2015   4/12/2015
# 126115      63058  201504130SAC   NBA        1     2015   4/13/2015
# 126137      63069  201504150LAL   NBA        0     2015   4/15/2015
#
#         seasongame  is_playoffs team_id fran_id  pts      elo_i      elo_n  \
# ...

# %%
df[filter_fran_lakers]['team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
filter_fran_nuggets = df['fran_id'] == 'Nuggets'
df[filter_fran_nuggets]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 15173        7587  196710150DNR   ABA        0     1968  10/15/1967
# 15185        7593  196710170DNR   ABA        0     1968  10/17/1967
# 15201        7601  196710190OAK   ABA        1     1968  10/19/1967
# 15209        7605  196710200OAK   ABA        1     1968  10/20/1967
# 15281        7641  196710270PTP   ABA        1     1968  10/27/1967
# ...           ...           ...   ...      ...      ...         ...
# 126017      63009  201504080DEN   NBA        0     2015    4/8/2015
# 126046      63024  201504100DEN   NBA        0     2015   4/10/2015
# 126078      63040  201504120DEN   NBA        0     2015   4/12/2015
# 126104      63053  201504130LAC   NBA        1     2015   4/13/2015
# 126132      63067  201504150GSW   NBA        1     2015   4/15/2015
#
#         seasongame  is_playoffs team_id  fran_id  ...  win_equiv  opp_id  \
# 15173            1            0     DNR  Nuggets  ...  41.481869     ANA
# ...

# %%
df[filter_fran_nuggets]['team_id'].value_counts()
# Out:
# DEN    3312
# DNR     614
# DNA     194
# Name: team_id, dtype: int64

# %%
# df[filter_fran_nuggets]['date_game']
df[filter_fran_nuggets]['date_game'].min()
# Out:
# '1/1/1981'

# %%
df[filter_fran_nuggets]['date_game'].max()
# Out:
# '5/9/2009'

# %%
mnl_team = df['team_id'] == 'MNL'
df[mnl_team]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id   date_game  seasongame  \
# 1136        569  194811040BLB   NBA        1     1949   11/4/1948           1
# 1152        577  194811060WSC   NBA        1     1949   11/6/1948           2
# 1159        580  194811090BOS   NBA        1     1949   11/9/1948           3
# 1170        586  194811110NYK   NBA        1     1949  11/11/1948           4
# 1183        592  194811130PRO   NBA        1     1949  11/13/1948           5
# ...         ...           ...   ...      ...      ...         ...         ...
# 9701       4851  196003190LAL   NBA        0     1960   3/19/1960          80
# 9702       4852  196003200LAL   NBA        0     1960   3/20/1960          81
# 9709       4855  196003220STL   NBA        1     1960   3/22/1960          82
# 9711       4856  196003240LAL   NBA        0     1960   3/24/1960          83
# 9715       4858  196003260STL   NBA        1     1960   3/26/1960          84
#
# ...

# %%
df[mnl_team]['date_game'].agg(['min', 'max'])
# Out:
# min    1/1/1949
# max    4/9/1959
# Name: date_game, dtype: object

# %%
df[mnl_team]['pts'].sum()
# Out:
# 88229

# %%
bos_team = df['team_id'] == 'BOS'
df[bos_team]['pts'].sum()
# Out:
# 626484

# %% [markdown]
# ## Getting to Know Pandas' Data Structure

# %% [markdown]
# ### Understanding Series Objects

# %%
revenues = pd.Series([5555, 7000, 1980])

# %%
revenues
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64

# %%
revenues.values
# Out:
# array([5555, 7000, 1980], dtype=int64)

# %%
revenues.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
# initiating/creating Series with explicit index #1
city_revenues = pd.Series(
    [4200, 8000, 6500],
    index=["Amsterdam", "Toronto", "Tokyo"]
)
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
#positional index
city_revenues[0]
# Out:
# 4200

# %%
#label index
city_revenues['Amsterdam']
# Out:
# 4200

# %%
# city_revenues.value
city_revenues.keys()
# Out:
# Index(['Amsterdam', 'Toronto', 'Tokyo'], dtype='object')

# %%
# initiating/creating Series with explicit index #2
city_employee_count = pd.Series({"Amsterdam": 5, "Tokyo": 8})
city_employee_count
# Out:
# Amsterdam    5
# Tokyo        8
# dtype: int64

# %%
city_employee_count.keys()
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
"Tokyo" in city_employee_count
# Out:
# True

# %%
"New York" in city_employee_count
# Out:
# False

# %%
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_employee_count
# Out:
# Amsterdam    5
# Tokyo        8
# dtype: int64

# %% [markdown]
# ### Understanding DataFrame Objects

# %%
city_data = pd.DataFrame(
    {
        "revenue" : city_revenues,
        "employee_count" : city_employee_count
    }
)
city_data

# "NaN --> np.nan " NaN values adalah object nan ‘milik’ NumPy
# *) …by saying milik NumPy i mean  = bawaan = built-in object
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.index
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.values
# Out:
# array([[4.2e+03, 5.0e+00],
#        [6.5e+03, 8.0e+00],
#        [8.0e+03,     nan]])

# %%
city_data.axes[0] #rows
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.axes[1] # columns
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_data # a DataFrame --> keys() refers to columns
city_data.keys()
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_data # a DataFrame --> keys() refers to columns
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.keys()
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_employee_count # a Series --> keys() refers to index
city_employee_count.keys()
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
city_employee_count # a Series --> keys() refers to index
# Out:
# Amsterdam    5
# Tokyo        8
# dtype: int64

# %%
city_employee_count.keys()
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %% [markdown]
# ### Accessing Series Elements

# %% [markdown]
# #### Using the Indexing Operator

# %%
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_revenues['Toronto']
# Out:
# 8000

# %%
city_revenues[1]
# Out:
# 8000

# %%
city_revenues[-1]
# Out:
# 6500

# %%
city_revenues[1:]
# Out:
# Toronto    8000
# Tokyo      6500
# dtype: int64

# %%
city_revenues["Toronto":]
# Out:
# Toronto    8000
# Tokyo      6500
# dtype: int64

# %% [markdown]
# #### Using .loc dan .iloc

# %%
colors = pd.Series(
    ["red", "purple", "blue", "green", "yellow"],
    index=[1, 2, 3, 5, 8]
)

colors
# Out:
# 1       red
# 2    purple
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
colors.loc[1] #loc untuk manggil explicit indexnyaa
# Out:
# 'red'

# %%
colors.iloc[0] #iloc untuk manggil implicit indexnya
# Out:
# 'red'

# %%
'''''
- Slicing list python : start inclusive, stopnya exclusive
- Slicing loc : start inclusive, stopnya inclusive
- Slicing iloc: start inclusive, stopnya exclusive
'''''
# Out:
# "''\n- Slicing list python : start inclusive, stopnya exclusive\n- Slicing loc : start inclusive, stopnya inclusive\n- Slicing iloc: start inclusive, stopnya exclusive\n"

# %%
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_revenues.loc['Amsterdam']
# Out:
# 4200

# %%
city_revenues.loc['Toronto']
# Out:
# 8000

# %%
colors
# Out:
# 1       red
# 2    purple
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
colors.iloc[1:3]
# 1st, 2nd element only
# Out:
# 2    purple
# 3      blue
# dtype: object

# %%
colors.loc[2:5]
# Out:
# 2    purple
# 3      blue
# 5     green
# dtype: object

# %%
colors.loc[3:8]
# Out:
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
colors.iloc[-2]
# Out:
# 'green'

# %% [markdown]
# ### Acessing DataFrame Elements

# %% [markdown]
# #### Using the Indexing Operators

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
# city_data['revenue']
city_data.revenue
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: revenue, dtype: int64

# %%
# city_data['employee_count']
city_data.employee_count
# Out:
# Amsterdam    5.0
# Tokyo        8.0
# Toronto      NaN
# Name: employee_count, dtype: float64

# %%
toys = pd.DataFrame([
    {"name": "ball", "shape":"sphere"},
    {"name": "Rubik's cube", "shape": "cube"}
])
toys
# Out:
#            name   shape
# 0          ball  sphere
# 1  Rubik's cube    cube

# %%
toys["shape"]
# Out:
# 0    sphere
# 1      cube
# Name: shape, dtype: object

# %%
toys.shape
# Out:
# (2, 2)

# %% [markdown]
# #### Using .loc dan .iloc

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.loc["Amsterdam"]
# Out:
# revenue           4200.0
# employee_count       5.0
# Name: Amsterdam, dtype: float64

# %%
# city_data.loc["Tokyo": "Toronto"]
city_data.loc["Amsterdam": "Tokyo"]
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0

# %%
city_data.iloc[1]
# Out:
# revenue           6500.0
# employee_count       8.0
# Name: Tokyo, dtype: float64

# %%
# df.iloc[-2]
df.iloc[-2010]
# Out:
# gameorder               62153
# game_id          201412080WAS
# lg_id                     NBA
# _iscopy                     0
# year_id                  2015
# date_game           12/8/2014
# seasongame                 20
# is_playoffs                 0
# team_id                   WAS
# fran_id               Wizards
# pts                       133
# elo_i               1560.8662
# elo_n               1562.0968
# win_equiv           46.994286
# opp_id                    BOS
# opp_fran              Celtics
# opp_pts                   132
# opp_elo_i           1401.8522
# opp_elo_n           1400.6216
# game_location               H
# game_result                 W
# forecast             0.816229
# notes                     NaN
# Name: 124304, dtype: object

# %%
df.loc[124304]
# df.iloc[-2010]
# Out:
# gameorder               62153
# game_id          201412080WAS
# lg_id                     NBA
# _iscopy                     0
# year_id                  2015
# date_game           12/8/2014
# seasongame                 20
# is_playoffs                 0
# team_id                   WAS
# fran_id               Wizards
# pts                       133
# elo_i               1560.8662
# elo_n               1562.0968
# win_equiv           46.994286
# opp_id                    BOS
# opp_fran              Celtics
# opp_pts                   132
# opp_elo_i           1401.8522
# opp_elo_n           1400.6216
# game_location               H
# game_result                 W
# forecast             0.816229
# notes                     NaN
# Name: 124304, dtype: object

# %%
# masih using indexing
fran_nuggets = df['fran_id'] == 'Nuggets'
df[fran_nuggets][['team_id', 'forecast', 'pts']]
# Out:
#        team_id  forecast  pts
# 15173      DNR  0.646262  110
# 15185      DNR  0.646135   85
# 15201      DNR  0.332896  104
# 15209      DNR  0.380653  102
# 15281      DNR  0.372465   77
# ...        ...       ...  ...
# 126017     DEN  0.761086  119
# 126046     DEN  0.455074  143
# 126078     DEN  0.660072  122
# 126104     DEN  0.104638  103
# 126132     DEN  0.070418  126
#
# [4120 rows x 3 columns]

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.loc["Amsterdam":"Tokyo", "revenue"]
# Out:
# Amsterdam    4200
# Tokyo        6500
# Name: revenue, dtype: int64

# %%
city_data.loc["Amsterdam":"Tokyo", ["revenue", "employee_count"] ]
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0

# %%
df.loc[:5, ["fran_id", "opp_fran", "pts", "opp_pts"]]
# Out:
#     fran_id  opp_fran  pts  opp_pts
# 0   Huskies    Knicks   66       68
# 1    Knicks   Huskies   68       66
# 2     Stags    Knicks   63       47
# 3    Knicks     Stags   47       63
# 4   Falcons  Capitols   33       50
# 5  Capitols   Falcons   50       33

# %%
df.loc[5555:5559, ["fran_id", "opp_fran", "pts", "opp_pts"]]
# Out:
#       fran_id  opp_fran  pts  opp_pts
# 5555  Pistons  Warriors   83       56
# 5556  Celtics    Knicks   95       74
# 5557   Knicks   Celtics   74       95
# 5558    Kings    Sixers   81       86
# 5559   Sixers     Kings   86       81

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %% [markdown]
# ## Querying Your Dataset

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
current_decade = df[df["year_id"] > 2010]
current_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# ...

# %%
#current_decade = df[df["year_id"] > 2010] , di breakdown
games_after_2010 = df["year_id"] > 2010
current_decade = df[games_after_2010]
current_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# ...

# %%
games_by_year = df["year_id"] > 2004

# %%
current_decade = df[games_by_year]
current_decade
df.shape
# Out:
# (126314, 23)

# %%
# filter_not_null = df["notes"].notnull()
# games_with_notes = df[filter_not_null]
games_with_notes = df[df["notes"].notnull()]
games_with_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  ...  win_equiv  opp_id  \
# ...

# %%
games_with_notes.shape
# Out:
# (5424, 23)

# %%
ers = df[df["fran_id"].str.endswith("ers")]
ers
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 16              9  194611050DTF   NBA        1     1947  11/5/1946
# 20             11  194611070PRO   NBA        0     1947  11/7/1946
# 22             12  194611070STB   NBA        0     1947  11/7/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  ...  win_equiv  opp_id  \
# 7                1            0     PRO  Steamrollers  ...  41.540619     BOS
# ...

# %%
ers.shape
# Out:
# (27797, 23)

# %%
filt = (
    (df["_iscopy"] == 0) &
    (df["pts"] > 100) &
    (df["opp_pts"] > 100) &
    (df["team_id"] == "BLB")
)
df[filt]
# df[
#   (df["_iscopy"] == 0) &
#   (df["pts"] > 100) &
#   (df["opp_pts"] > 100) &
#   (df["team_id"] == "BLB")
# ]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 1726        864  194902260BLB   NBA        0     1949  2/26/1949          53
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
# 5825       2913  195402220BLB   NBA        0     1954  2/22/1954          60
#
#       is_playoffs team_id    fran_id  ...  win_equiv  opp_id  opp_fran  \
# 1726            0     BLB  Baltimore  ...  38.557545     MNL    Lakers
# 4890            0     BLB  Baltimore  ...  25.797792     BOS   Celtics
# 4909            0     BLB  Baltimore  ...  24.876236     MNL    Lakers
# 5208            0     BLB  Baltimore  ...  19.579676     NYK    Knicks
# 5825            0     BLB  Baltimore  ...  20.736986     BOS   Celtics
#
# ...

# %%
df[
    (df["_iscopy"] == 0) &
    (df["team_id"].str.startswith("LA")) &
    (df["year_id"] == 1992) &
    (df["notes"].notnull())
]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id date_game  seasongame  \
# 68901      34451  199205030LAC   NBA        0     1992  5/3/1992          86
# 68903      34452  199205030LAL   NBA        0     1992  5/3/1992          86
#
#        is_playoffs team_id   fran_id  ...  win_equiv  opp_id      opp_fran  \
# 68901            1     LAC  Clippers  ...  47.888252     UTA          Jazz
# 68903            1     LAL    Lakers  ...  39.395412     POR  Trailblazers
#
#        opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  forecast  \
# 68901      107  1647.5092  1638.4095              H            W  0.499125
# 68903      102  1655.1210  1670.3677              H            L  0.406874
#
#                                             notes
# 68901  at Anaheim, CA (Anaheim Convention Center)
# 68903                            at Las Vegas, NV
#
# [2 rows x 23 columns]

# %% [markdown]
# ##  Grouping and Aggregating Your Data

# %%
city_revenues.sum()
# Out:
# 18700

# %%
city_revenues.max()
# Out:
# 8000

# %%
city_revenues.min()
# Out:
# 4200

# %%
city_revenues.mean()
# Out:
# 6233.333333333333

# %%
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
points = df['pts']
# points # n rows of data pts
# points.sum()
df['pts'].sum()
# Out:
# 12976235

# %%
"pts" in df.keys()
# Out:
# True

# %%
# df.groupby('fran_id', sort=False)['pts'].sum()
# sort=Truenya buat by colom yang di-group
df.groupby('fran_id', sort=False)['pts'].sum().sort_values() # sort nilai sumnya
# Out:
# fran_id
# Ironmen           3674
# Falcons           3797
# Huskies           3995
# Rebels            4474
# Jets              4482
# Denver            4818
# Waterloo          4921
# Redskins          5372
# Packers           6193
# Steamrollers     12372
# Bombers          17793
# Stags            20398
# Capitols         22387
# Olympians        22864
# Sails            30080
# Baltimore        37219
# Floridians       49568
# Condors          49642
# Sounds           75582
# Hornets          84489
# Stars            84940
# Spirits          85874
# Squires          91127
# Colonels         94435
# Grizzlies       157683
# Raptors         158370
# Timberwolves    207693
# Magic           219436
# Pelicans        220794
# Heat            229103
# Mavericks       309239
# Jazz            363155
# Cavaliers       380416
# Clippers        380523
# Trailblazers    402695
# Nets            417809
# Bucks           418326
# Rockets         432504
# Bulls           437269
# ...

# %%
df.groupby("team_id", sort=False)["pts"]

type(city_revenues)
# Out:
# pandas.core.series.Series

# %%
df.groupby("team_id", sort=False)["pts"]

# %%
type(city_revenues)
# Out:
# pandas.core.series.Series

# %%
df.groupby("team_id", sort=False)["pts"].sum()
# Out:
# team_id
# TRH      3995
# NYK    582497
# CHS     20398
# DTF      3797
# WSC     22387
#         ...
# NOK     15444
# OKC     64930
# BRK     26481
# NOP     16727
# CHO      7721
# Name: pts, Length: 104, dtype: int64

# %%
df.groupby("team_id", sort=False)["pts"]

# %%
type(city_revenues)
# Out:
# pandas.core.series.Series

# %%
df[
    (df["fran_id"] == "Spurs") &
    (df["year_id"] > 2010)
].groupby(["year_id", "game_result"])["game_id"].count()
# Out:
# year_id  game_result
# 2011     L              25
#          W              63
# 2012     L              20
#          W              60
# 2013     L              30
#          W              73
# 2014     L              27
#          W              78
# 2015     L              31
#          W              58
# Name: game_id, dtype: int64

# %%
df[
    (df["fran_id"] == "Spurs") &
    (df["year_id"] > 2010)
].groupby(["game_result"])["game_id"].count()
# Out:
# game_result
# L    133
# W    332
# Name: game_id, dtype: int64

# %%
df[
    (df["fran_id"] == "Warriors") &
    (df["year_id"] == 2015)
].groupby(["is_playoffs", "game_result"])["game_id"].count()
# Out:
# is_playoffs  game_result
# 0            L              15
#              W              67
# 1            L               5
#              W              16
# Name: game_id, dtype: int64

# %%
df[
    (df["fran_id"] == "Warriors") &
    (df["year_id"] == 2015)
].groupby(["game_result", "is_playoffs"])["game_id"].count()
# Out:
# game_result  is_playoffs
# L            0              15
#              1               5
# W            0              67
#              1              16
# Name: game_id, dtype: int64

# %%
nba['difference'] = nba.pts - nba.opp_pts
# nba['difference'] =  nba.["pts"] - nba["opp_pts"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16280/2716225239.py in <module>
# ----> 1 nba['difference'] = nba.pts - nba.opp_pts
#       2 # nba['difference'] =  nba.["pts"] - nba["opp_pts"]
#
# NameError: name 'nba' is not defined

# %% [markdown]
# ## Manipulating Columns

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
df.shape
# Out:
# (126314, 23)

# %%
nba = df.copy()
nba.shape
# Out:
# (126314, 23)

# %%
nba['difference'] = nba.pts - nba.opp_pts
# nba['difference'] =  nba.["pts"] - nba["opp_pts"]
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  opp_id   opp_fran  \
# 0                1            0     TRH    Huskies  ...     NYK     Knicks
# ...

# %%
nba.shape
# Out:
# (126314, 24)

# %%
nba[['pts', 'opp_pts', 'difference']]
# Out:
#         pts  opp_pts  difference
# 0        66       68          -2
# 1        68       66           2
# 2        63       47          16
# 3        47       63         -16
# 4        33       50         -17
# ...     ...      ...         ...
# 126309   82      103         -21
# 126310  104       91          13
# 126311   91      104         -13
# 126312   97      105          -8
# 126313  105       97           8
#
# [126314 rows x 3 columns]

# %%
nba["difference"].max()
# Out:
# 68

# %%
nba["difference"].value_counts()
# Out:
# -2     4115
#  2     4115
# -5     4001
#  5     4001
# -7     3912
#        ...
#  63       1
#  68       1
# -68       1
# -65       1
#  65       1
# Name: difference, Length: 126, dtype: int64

# %%
renamed_nba = nba.rename(
    columns={"game_result":"result", "game_location":"location"}
)
renamed_nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  object
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  int64
#  11  elo_i        126314 non-null  float64
#  12  elo_n        126314 non-null  float64
#  13  win_equiv    126314 non-null  float64
#  14  opp_id       126314 non-null  object
#  15  opp_fran     126314 non-null  object
#  16  opp_pts      126314 non-null  int64
#  17  opp_elo_i    126314 non-null  float64
# ...

# %%
renamed_nba[['result', 'location']]
# Out:
#        result location
# 0           L        H
# 1           W        A
# 2           W        H
# 3           L        A
# 4           L        H
# ...       ...      ...
# 126309      L        H
# 126310      W        H
# 126311      L        A
# 126312      L        H
# 126313      W        A
#
# [126314 rows x 2 columns]

# %%
nba.shape
# Out:
# (126314, 24)

# %%
# (!) karena ini perintah untuk delete column, jadi ketika sudah >1x di run akan muncul error kolom tidak ditemukan, that’s okay
 
# nba.drop('elo_i', axis=1)
nba.drop('elo_i', axis=1, inplace=True)
nba
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21288/912673891.py in <module>
#       2
#       3 # nba.drop('elo_i', axis=1)
# ----> 4 nba.drop('elo_i', axis=1, inplace=True)
#       5 nba
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
elo_columns = ["elo_n", "opp_elo_i", "opp_elo_n"]
nba.drop(elo_columns, inplace=True, axis=1)
nba.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21288/3010435242.py in <module>
#       1 elo_columns = ["elo_n", "opp_elo_i", "opp_elo_n"]
# ----> 2 nba.drop(elo_columns, inplace=True, axis=1)
#       3 nba.shape
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %% [markdown]
# ## Specifying Data Types

# %%
nba["date_game"] = pd.to_datetime(nba["date_game"])

# %%
nba["date_game"].dtype
# Out:
# dtype('<M8[ns]')

# %%
nba["game_location"].unique()
# Out:
# array(['H', 'A', 'N'], dtype=object)

# %%
nba["game_location"].nunique() #number of unique values
# Out:
# 3

# %%
nba["game_location"].value_counts()
# Out:
# H    63138
# A    63138
# N       38
# Name: game_location, dtype: int64

# %%
nba["game_location"] = pd.Categorical(nba["game_location"])
nba["game_location"].dtype
# Out:
# CategoricalDtype(categories=['A', 'H', 'N'], ordered=False)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  win_equiv      126314 non-null  float64
#  12  opp_id         126314 non-null  object
#  13  opp_fran       126314 non-null  object
#  14  opp_pts        126314 non-null  int64
#  15  game_location  126314 non-null  category
#  16  game_result    126314 non-null  object
# ...

# %% [markdown]
# ##  Missing Values

# %%
'''
NaN ← object NumPy, nan
None ← object Python, None
kedua ini merupakan missing values yang dikenali Pandas
'''

# %%
rows_without_missing_data = nba.dropna() #axis = 0 -- baris
# rows_without_missing_data
rows_without_missing_data.shape
# Out:
# (5424, 20)

# %%
data_without_missing_columns = nba.dropna(axis=1) # -- kolom
# data_without_missing_columns
data_without_missing_columns.shape
# Out:
# (126314, 19)

# %%
data_with_default_notes = df.copy()
data_with_default_notes.shape
# Out:
# (126314, 23)

# %%
data_with_default_notes["notes"].fillna(
    value="no notes at all",
    inplace=True
)
data_with_default_notes['notes']
# Out:
# 0         no notes at all
# 1         no notes at all
# 2         no notes at all
# 3         no notes at all
# 4         no notes at all
#                ...
# 126309    no notes at all
# 126310    no notes at all
# 126311    no notes at all
# 126312    no notes at all
# 126313    no notes at all
# Name: notes, Length: 126314, dtype: object

# %%
data_with_default_notes['notes'].describe()

# %% [markdown]
# ## Invalid Values

# %%
df.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %%
nba[nba["pts"] == 0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 26684      13343  197210260VIR   ABA        1     1973 1972-10-26           7
#
#        is_playoffs team_id  fran_id  pts  win_equiv opp_id opp_fran  opp_pts  \
# 26684            0     DNR  Nuggets    0  40.408863    VIR  Squires        2
#
#       game_location game_result  forecast                           notes  \
# 26684             A           L  0.328948  at Richmond VA; forfeit to VIR
#
#        difference
# 26684          -2

# %% [markdown]
# ### Incosistent Values

# %%
nba[(nba["pts"] > nba["opp_pts"]) & (nba["game_result"] != 'W')]
# Out:
# Empty DataFrame
# Columns: [gameorder, game_id, lg_id, _iscopy, year_id, date_game, seasongame, is_playoffs, team_id, fran_id, pts, win_equiv, opp_id, opp_fran, opp_pts, game_location, game_result, forecast, notes, difference]
# Index: []

# %%
nba[(nba["pts"] > nba["opp_pts"]) & (nba["game_result"] != 'W')].empty
# Out:
# True

# %% [markdown]
# ## Combining Multiple Datasets

# %%
further_city_data = pd.DataFrame(
    {"revenue": [7000, 3400], "employee_count": [2, 2]},
    index=["New York", "Barcelona"]
)
further_city_data
# Out:
#            revenue  employee_count
# New York      7000               2
# Barcelona     3400               2

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
all_city_data = pd.concat([city_data, further_city_data], sort=False) #axis = 0
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3400             2.0

# %%
city_countries = pd.DataFrame(
    {"country": ["Holland", "Japan", "Holland", "Canada", "Spain"], "capital": [1, 1, 0, 0, 0]},
    index=["Amsterdam", "Tokyo", "Rotterdam", "Toronto", "Barcelona"]
)
city_countries
# Out:
#            country  capital
# Amsterdam  Holland        1
# Tokyo        Japan        1
# Rotterdam  Holland        0
# Toronto     Canada        0
# Barcelona    Spain        0

# %%
cities = pd.concat([all_city_data, city_countries], axis=1, sort=False)
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
pd.concat([all_city_data, city_countries], axis=1, join="inner")
# Out:
#            revenue  employee_count  country  capital
# Amsterdam     4200             5.0  Holland        1
# Tokyo         6500             8.0    Japan        1
# Toronto       8000             NaN   Canada        0
# Barcelona     3400             2.0    Spain        0

# %%
countries = pd.DataFrame(
    {
        "population_millions": [17, 127, 37],
        "continent": ["Europe", "Asia", "North America"]
    },
    index=["Holland", "Japan", "Canada"]
)
countries
# Out:
#          population_millions      continent
# Holland                   17         Europe
# Japan                    127           Asia
# Canada                    37  North America

# %%
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
pd.merge(cities, countries, left_on="country", right_index=True)
# Out:
#            revenue  employee_count  country  capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                   17
# Rotterdam      NaN             NaN  Holland      0.0                   17
# Tokyo       6500.0             8.0    Japan      1.0                  127
# Toronto     8000.0             NaN   Canada      0.0                   37
#
#                continent
# Amsterdam         Europe
# Rotterdam         Europe
# Tokyo               Asia
# Toronto    North America

# %%
pd.merge(
    cities,
    countries,
    left_on="country",
    right_index=True,
    how="left"
)

# %% [markdown]
# ## Visualizing Your Pandas DataFrame

# %%
# %matplotlib inline

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66  40.294830    NYK
# ...

# %%
nba[ nba["fran_id"] == "Knicks"].groupby("year_id").sum().plot()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:633: UserWarning: The handle <matplotlib.lines.Line2D object at 0x00000210A006C790> has a label of '_iscopy' which cannot be automatically added to the legend.
#   ax.legend(handles, labels, loc="best", title=title)
# <AxesSubplot:xlabel='year_id'>

# %%
nba[ nba["fran_id"] == "Knicks"].groupby("year_id").sum()
# Out:
#          gameorder  _iscopy  seasongame  is_playoffs   pts    win_equiv  \
# year_id
# 1947         11866       33        2145            5  4234  2730.265028
# 1948         22863       26        1326            3  3815  2218.581962
# 1949         50497       32        2211            6  5253  2864.656232
# 1950         90369       39        2701            5  5924  3496.024098
# 1951        140228       45        3240           14  6814  3518.238440
# ...            ...      ...         ...          ...   ...          ...
# 2011       4942956       43        3741            4  9097  3335.227006
# 2012       4165475       36        2556            5  6872  2923.475945
# 2013       5633393       46        4465           12  9259  4703.103214
# 2014       5013942       41        3403            0  8084  3093.575463
# 2015       5121037       41        3403            0  7535  2157.628465
#
#          opp_pts   forecast  difference
# year_id
# 1947        4218  32.795191          16
# ...

# %%
nba["fran_id"].value_counts().head(10).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
nba["fran_id"].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...
